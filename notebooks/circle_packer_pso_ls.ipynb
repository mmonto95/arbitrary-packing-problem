# %%
# %env DISABLE_PROGRESS_BAR=True
# Out:
# env: DISABLE_PROGRESS_BAR=True

# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerPSOLS
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']
name = ALL_TESTS[0]['name']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
    test_name=name
)
packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 2min 56s, sys: 5.26 s, total: 3min 1s
# Wall time: 3min 2s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 25 - Score: 0.296

# %%
container = ALL_TESTS[1]['container']
radius = ALL_TESTS[1]['radius']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=30,
    n_iterations=10,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()
# Out:
# CPU times: user 1min 15s, sys: 2.38 s, total: 1min 17s
# Wall time: 1min 17s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[3]['container']
radius = ALL_TESTS[3]['radius']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=30,
    n_iterations=10,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()
# Out:
# CPU times: user 11min 18s, sys: 2.38 s, total: 11min 20s
# Wall time: 11min 24s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 12 - Score: 0.316

# %%
container = ALL_TESTS[5]['container']
radius = ALL_TESTS[5]['radius']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=30,
    n_iterations=10,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()
# Out:
# CPU times: user 9min 52s, sys: 1.11 s, total: 9min 53s
# Wall time: 9min 54s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 8 - Score: 0.419

# %%
container = ALL_TESTS[7]['container']
radius = ALL_TESTS[7]['radius']

# %%
# %%time
packer = CirclePackerPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=30,
    n_iterations=10,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
