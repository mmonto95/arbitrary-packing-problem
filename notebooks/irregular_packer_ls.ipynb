# %%
from shapely.geometry import GeometryCollection

from packer import IrregularPackerGBFLS
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
shapes = ALL_TESTS[0]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=3,
    n_neighbors=5,
    step_portion=2,
    queue_length=3,
    n_rotations=32,
    n_search=1
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 35.8 s, sys: 381 ms, total: 36.2 s
# Wall time: 36.5 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 5 - Score: 0.277

# %%
container = ALL_TESTS[1]['container']
shapes = ALL_TESTS[1]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=12,
    step_portion=8,
    n_rotations=16,
    queue_length=3,
    n_search=10
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 23.4 s, sys: 263 ms, total: 23.7 s
# Wall time: 23.8 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 111 - Score: 0.471

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=12,
    step_portion=8,
    n_rotations=16,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 2min 33s, sys: 1.75 s, total: 2min 35s
# Wall time: 2min 35s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 112 - Score: 0.47

# %%
container = ALL_TESTS[2]['container']
shapes = ALL_TESTS[2]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=12,
    step_portion=2,
    n_rotations=32,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 4min 52s, sys: 3.24 s, total: 4min 55s
# Wall time: 4min 57s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 4 - Score: 0.402

# %%
container = ALL_TESTS[3]['container']
shapes = ALL_TESTS[3]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 6min 3s, sys: 4.06 s, total: 6min 7s
# Wall time: 6min 8s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 85 - Score: 0.408

# %%
container = ALL_TESTS[4]['container']
shapes = ALL_TESTS[4]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=3,
    n_neighbors=5,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 4min 22s, sys: 2.51 s, total: 4min 25s
# Wall time: 4min 26s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 2 - Score: 0.372

# %%
container = ALL_TESTS[5]['container']
shapes = ALL_TESTS[5]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 7min 55s, sys: 4.56 s, total: 8min
# Wall time: 8min 2s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 57 - Score: 0.331

# %%
container = ALL_TESTS[6]['container']
shapes = ALL_TESTS[6]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=8,
    step_portion=2,
    queue_length=10,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 4min 47s, sys: 3.06 s, total: 4min 50s
# Wall time: 4min 51s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 3 - Score: 0.637

# %%
container = ALL_TESTS[7]['container']
shapes = ALL_TESTS[7]['shapes']

# %%
# %%time
packer = IrregularPackerGBFLS(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
