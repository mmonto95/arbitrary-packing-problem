# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerBeeStrict
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3
)
df_sol = packer.pack()
# Out:
# CPU times: user 10.1 s, sys: 339 ms, total: 10.4 s
# Wall time: 10.5 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 21 - Score: 0.313

# %%
container = ALL_TESTS[1]['container']
radius = ALL_TESTS[1]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3
)
df_sol = packer.pack()
# Out:
# CPU times: user 7min 18s, sys: 8.35 s, total: 7min 27s
# Wall time: 7min 28s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 349 - Score: 0.286

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=30,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3
)
df_sol = packer.pack()
# Out:
# CPU times: user 31.8 s, sys: 717 ms, total: 32.5 s
# Wall time: 32.6 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 13 - Score: 0.476

# %%
container = ALL_TESTS[3]['container']
radius = ALL_TESTS[3]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3
)
df_sol = packer.pack()
# Out:
# CPU times: user 8min 39s, sys: 8.04 s, total: 8min 47s
# Wall time: 14min 15s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 266 - Score: 0.33

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3
)
df_sol = packer.pack()
# Out:
# CPU times: user 16.2 s, sys: 286 ms, total: 16.5 s
# Wall time: 16.6 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 6 - Score: 0.564

# %%
container = ALL_TESTS[5]['container']
radius = ALL_TESTS[5]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=16,
    step_portion=16,
    queue_length=8
)
df_sol = packer.pack()
# Out:
# CPU times: user 58min 40s, sys: 44.7 s, total: 59min 24s
# Wall time: 1h 14s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 132 - Score: 0.4

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3
)
df_sol = packer.pack()
# Out:
# CPU times: user 14.1 s, sys: 393 ms, total: 14.5 s
# Wall time: 14.6 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 3 - Score: 0.732

# %%
container = ALL_TESTS[7]['container']
radius = ALL_TESTS[7]['radius']

# %%
# %%time
packer = CirclePackerBeeStrict(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3
)
df_sol = packer.pack()
# Out:
# CPU times: user 15min 45s, sys: 7.86 s, total: 15min 52s
# Wall time: 15min 55s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 104 - Score: 0.472
