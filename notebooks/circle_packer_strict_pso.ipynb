# %%
# %env DISABLE_PROGRESS_BAR=True

# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerStrictPSO
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']

# %%
# %%time
packer = CirclePackerStrictPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 9 - Score: 0.705

# %%
# container = ALL_TESTS[1]['container']
# radius = ALL_TESTS[1]['radius']

# %%
# %%time
# packer = CirclePackerStrictPSO(
#     container,
#     radius,
#     phi_p=1,
#     phi_g=1,
#     w=0.1,
#     n_particles=100,
#     n_iterations=20,
#     n_circle_iter=8,
# )
# packer.pack()
# Out:
# CPU times: user 1min 15s, sys: 2.38 s, total: 1min 17s
# Wall time: 1min 17s

# %%
# _packer = packer.get_packer()
# df_sol = _packer.drop_external(packer.global_optimum_position.copy())
# _packer.drop_intersected(df_sol)
# print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
# GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerStrictPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
# container = ALL_TESTS[3]['container']
# radius = ALL_TESTS[3]['radius']

# %%
# %%time
# packer = CirclePackerStrictPSO(
#     container,
#     radius,
#     phi_p=1,
#     phi_g=1,
#     w=0.1,
#     n_particles=100,
#     n_iterations=20,
#     n_circle_iter=8,
# )
# packer.pack()

# %%
# _packer = packer.get_packer()
# df_sol = _packer.drop_external(packer.global_optimum_position.copy())
# _packer.drop_intersected(df_sol)
# print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
# GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerStrictPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
# container = ALL_TESTS[5]['container']
# radius = ALL_TESTS[5]['radius']

# %%
# %%time
# packer = CirclePackerStrictPSO(
#     container,
#     radius,
#     phi_p=1,
#     phi_g=1,
#     w=0.1,
#     n_particles=100,
#     n_iterations=20,
#     n_circle_iter=8,
# )
# packer.pack()

# %%
# _packer = packer.get_packer()
# df_sol = _packer.drop_external(packer.global_optimum_position.copy())
# _packer.drop_intersected(df_sol)
# print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
# GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerStrictPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=500,
    n_iterations=30,
    n_circle_iter=12,
)
packer.pack()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
# CPU times: user 6min 5s, sys: 1.74 s, total: 6min 7s
# Wall time: 6min 8s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 3 - Score: 0.732

# %%
# container = ALL_TESTS[7]['container']
# radius = ALL_TESTS[7]['radius']

# %%
# %%time
# packer = CirclePackerStrictPSO(
#     container,
#     radius,
#     phi_p=1,
#     phi_g=1,
#     w=0.1,
#     n_particles=100,
#     n_iterations=20,
#     n_circle_iter=8,
# )
# packer.pack()

# %%
# _packer = packer.get_packer()
# df_sol = _packer.drop_external(packer.global_optimum_position.copy())
# _packer.drop_intersected(df_sol)
# print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
# GeometryCollection([container, *df_sol['item']])
