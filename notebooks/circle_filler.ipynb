# %%
import json
from shapely.geometry import shape, Point, GeometryCollection
from polygon_filler import PolygonFiller, PolygonFillerStrict, PolygonFillerBeeInitialization, PolygonFillerBeeStrict

# %%
with open('../shapes/not_uniform_shape.json', 'r') as file:
    geometry = json.load(file)

# %%
polygon = shape(geometry)

# %%
polygon

# %%
radius = 0.02

# %%
circle = Point([0, 0]).buffer(radius)

# %%
GeometryCollection([polygon, circle])

# %%
filler = PolygonFiller(geometry, radius)
# filler = PolygonFiller(geometry, radius, shots=2)

# %%
df = filler.fill()

# %%
df
# Out:
#            x         y     neighbors        p_area    c_area    wrong_area  \
# 0  -0.002790 -0.036884        [3, 1]  8.217448e+00  1.276275  9.493723e+00
# 1  -0.002790  0.002828        [4, 0]  1.200794e+01  1.276275  1.328421e+01
# 2  -0.002790  0.092253        [6, 1]  1.470556e+00  0.000000  1.470556e+00
# 3   0.033963 -0.046884     [0, 7, 4]  1.311292e+01  1.276275  1.438919e+01
# 4   0.033963 -0.007172  [1, 8, 3, 5]  0.000000e+00  1.276275  1.276275e+00
# 5   0.023963  0.032540     [9, 4, 6]  2.842171e-14  0.000000  2.842171e-14
# 6   0.033963  0.072253    [2, 10, 5] -2.842171e-14  0.000000 -2.842171e-14
# 7   0.080717 -0.056884        [3, 8]  0.000000e+00  0.000000  0.000000e+00
# 8   0.080717 -0.007172     [4, 7, 9]  0.000000e+00  0.000000  0.000000e+00
# 9   0.070717  0.032540    [5, 8, 10]  0.000000e+00  0.000000  0.000000e+00
# 10  0.080717  0.072253        [6, 9] -4.263256e-14  0.000000 -4.263256e-14
#
#     locked
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9    False
# 10   False

# %%
x = df['x'].values
y = df['y'].values

# %%
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]

# %%
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFiller(geometry, radius, shots=2)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFiller(geometry, radius, shots=10)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerStrict(geometry, radius)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerStrict(geometry, radius, shots=2)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFiller(geometry, radius, shots=2, intersection_threshold=40)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerStrict(geometry, radius, shots=2, intersection_threshold=40)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeInitialization(geometry, radius)
circles = [Point([i, j]).buffer(radius) for i, j in filler.initialize_circles()]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeInitialization(geometry, radius)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeInitialization(geometry, radius, shots=2)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeInitialization(geometry, radius, shots=3)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeInitialization(geometry, radius, intersection_threshold=90)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeInitialization(geometry, radius, intersection_threshold=90, shots=2)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeStrict(geometry, radius)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerStrict(geometry, radius, intersection_threshold=40)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerBeeStrict(geometry, radius, intersection_threshold=20)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])

# %%
filler = PolygonFillerStrict(geometry, radius, intersection_threshold=20, shots=5)
df = filler.fill()
x = df['x'].values
y = df['y'].values
circles = [Point([i, j]).buffer(radius) for i, j in zip(x, y)]
GeometryCollection([polygon, *circles])
