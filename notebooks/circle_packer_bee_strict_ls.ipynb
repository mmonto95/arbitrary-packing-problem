# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerBeeStrictLS
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=1
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/1 [00:00<?, ?it/s]
# CPU times: user 10.5 s, sys: 225 ms, total: 10.8 s
# Wall time: 10.9 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 21 - Score: 0.313

# %%
container = ALL_TESTS[1]['container']
radius = ALL_TESTS[1]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=30,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3,
    n_search=1
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/1 [00:00<?, ?it/s]
# CPU times: user 35.3 s, sys: 643 ms, total: 35.9 s
# Wall time: 36.6 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 13 - Score: 0.476

# %%
container = ALL_TESTS[3]['container']
radius = ALL_TESTS[3]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=8,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()
# Out:
# Finished first optimization step
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 11 s, sys: 320 ms, total: 11.3 s
# Wall time: 11.7 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 6 - Score: 0.564

# %%
container = ALL_TESTS[5]['container']
radius = ALL_TESTS[5]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[7]['container']
radius = ALL_TESTS[7]['radius']

# %%
# %%time
packer = CirclePackerBeeStrictLS(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
