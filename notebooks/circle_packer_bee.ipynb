# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerBee
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 10.7 s, sys: 373 ms, total: 11.1 s
# Wall time: 11.1 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 33 - Score: 0.163

# %%
container = ALL_TESTS[1]['container']
radius = ALL_TESTS[1]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 1min 15s, sys: 2.38 s, total: 1min 17s
# Wall time: 1min 17s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 417 - Score: 0.172

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 11.2 s, sys: 243 ms, total: 11.5 s
# Wall time: 11.5 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 32 - Score: 0.342

# %%
container = ALL_TESTS[3]['container']
radius = ALL_TESTS[3]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 54.4 s, sys: 822 ms, total: 55.2 s
# Wall time: 55.3 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 352 - Score: 0.171

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 5.57 s, sys: 145 ms, total: 5.72 s
# Wall time: 5.75 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 18 - Score: 0.376

# %%
container = ALL_TESTS[5]['container']
radius = ALL_TESTS[5]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 43.7 s, sys: 1.3 s, total: 45 s
# Wall time: 45.2 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 194 - Score: 0.163

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 5.01 s, sys: 116 ms, total: 5.13 s
# Wall time: 5.17 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 17 - Score: 0.581

# %%
container = ALL_TESTS[7]['container']
radius = ALL_TESTS[7]['radius']

# %%
# %%time
packer = CirclePackerBee(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5
)
df_sol = packer.pack()
# Out:
# CPU times: user 46.7 s, sys: 1.17 s, total: 47.8 s
# Wall time: 48 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 180 - Score: 0.182
