# %%
from shapely.geometry import GeometryCollection

from packer import IrregularPackerGridBF
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
shapes = ALL_TESTS[0]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=3,
    n_neighbors=5,
    step_portion=2,
    queue_length=3,
    n_rotations=32
)
df_sol = packer.pack()

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[1]['container']
shapes = ALL_TESTS[1]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=12,
    step_portion=8,
    n_rotations=16,
    queue_length=3
)
df_sol = packer.pack()

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[2]['container']
shapes = ALL_TESTS[2]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=12,
    step_portion=2,
    n_rotations=32,
    queue_length=3
)
df_sol = packer.pack()

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[3]['container']
shapes = ALL_TESTS[3]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
)
df_sol = packer.pack()

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[4]['container']
shapes = ALL_TESTS[4]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=3,
    n_neighbors=5,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
)
df_sol = packer.pack()

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[5]['container']
shapes = ALL_TESTS[5]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
)
df_sol = packer.pack()

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 55 - Score: 0.338

# %%
container = ALL_TESTS[6]['container']
shapes = ALL_TESTS[6]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=8,
    step_portion=2,
    queue_length=10,
    n_rotations=32,
)
df_sol = packer.pack()
# Out:
# CPU times: user 370 ms, sys: 12.3 ms, total: 382 ms
# Wall time: 384 ms

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 2 - Score: 0.656

# %%
container = ALL_TESTS[7]['container']
shapes = ALL_TESTS[7]['shapes']

# %%
# %%time
packer = IrregularPackerGridBF(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
)
df_sol = packer.pack()
# Out:
# CPU times: user 12 s, sys: 131 ms, total: 12.1 s
# Wall time: 12.2 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 48 - Score: 0.341
