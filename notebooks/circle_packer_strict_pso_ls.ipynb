# %%
# %env DISABLE_PROGRESS_BAR=True

# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerStrictPSOLS
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']
name = ALL_TESTS[0]['name']

# %%
# %%time
packer = CirclePackerStrictPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
    test_name=name
)
packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 1min 21s, sys: 1.1 s, total: 1min 22s
# Wall time: 1min 22s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 14 - Score: 0.542

# %%
container = ALL_TESTS[1]['container']
radius = ALL_TESTS[1]['radius']

# %%
# %%time
packer = CirclePackerStrictPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=10,
    n_iterations=5,
    n_circle_iter=8,
    intersection_threshold=30,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=16,
    queue_length=5
)
packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# CPU times: user 54min 7s, sys: 30.8 s, total: 54min 38s
# Wall time: 55min 26s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 146 - Score: 0.701

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerStrictPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
# container = ALL_TESTS[3]['container']
# radius = ALL_TESTS[3]['radius']

# %%
# %%time
# packer = CirclePackerStrictPSOLS(
#     container,
#     radius,
#     phi_p=1,
#     phi_g=1,
#     w=0.1,
#     n_particles=100,
#     n_iterations=20,
#     n_circle_iter=16,
#     intersection_threshold=20,
#     max_iter=1000,
#     shots=10,
#     n_neighbors=10,
#     step_portion=16,
#     queue_length=5,
# )
# packer.pack()

# %%
# _packer = packer.get_packer()
# df_sol = _packer.drop_external(packer.global_optimum_position.copy())
# _packer.drop_intersected(df_sol)
# print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
# GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerStrictPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
# container = ALL_TESTS[5]['container']
# radius = ALL_TESTS[5]['radius']

# %%
# %%time
# packer = CirclePackerStrictPSOLS(
#     container,
#     radius,
#     phi_p=1,
#     phi_g=1,
#     w=0.1,
#     n_particles=100,
#     n_iterations=20,
#     n_circle_iter=16,
#     intersection_threshold=20,
#     max_iter=1000,
#     shots=10,
#     n_neighbors=10,
#     step_portion=16,
#     queue_length=5,
# )
# packer.pack()

# %%
# _packer = packer.get_packer()
# df_sol = _packer.drop_external(packer.global_optimum_position.copy())
# _packer.drop_intersected(df_sol)
# print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
# GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerStrictPSOLS(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=16,
    intersection_threshold=20,
    max_iter=1000,
    shots=10,
    n_neighbors=10,
    step_portion=16,
    queue_length=5,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
# container = ALL_TESTS[7]['container']
# radius = ALL_TESTS[7]['radius']

# %%
# %%time
# packer = CirclePackerStrictPSOLS(
#     container,
#     radius,
#     phi_p=1,
#     phi_g=1,
#     w=0.1,
#     n_particles=100,
#     n_iterations=20,
#     n_circle_iter=16,
#     intersection_threshold=20,
#     max_iter=1000,
#     shots=10,
#     n_neighbors=10,
#     step_portion=16,
#     queue_length=5,
# )
# packer.pack()

# %%
# _packer = packer.get_packer()
# df_sol = _packer.drop_external(packer.global_optimum_position.copy())
# _packer.drop_intersected(df_sol)
# print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
# GeometryCollection([container, *df_sol['item']])
