# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerBeeIntensification
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 1min 32s, sys: 941 ms, total: 1min 33s
# Wall time: 1min 33s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 15 - Score: 0.509

# %%
container = ALL_TESTS[1]['container']
radius = ALL_TESTS[1]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=10
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=30,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[3]['container']
radius = ALL_TESTS[3]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=10
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 22.1 s, sys: 247 ms, total: 22.4 s
# Wall time: 22.4 s

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 6 - Score: 0.564

# %%
container = ALL_TESTS[5]['container']
radius = ALL_TESTS[5]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=40,
    max_iter=1000,
    shots=5,
    n_neighbors=8,
    step_portion=2,
    queue_length=3,
    n_search=10
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[7]['container']
radius = ALL_TESTS[7]['radius']

# %%
# %%time
packer = CirclePackerBeeIntensification(
    container,
    radius,
    intersection_threshold=20,
    max_iter=1000,
    shots=5,
    n_neighbors=16,
    step_portion=16,
    queue_length=3,
    n_search=10
)
df_sol = packer.pack()

# %%
print('Number of circles:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
