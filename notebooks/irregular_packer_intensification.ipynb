# %%
from shapely.geometry import GeometryCollection

from packer import IrregularPackerIntensification
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
shapes = ALL_TESTS[0]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=3,
    n_neighbors=5,
    step_portion=2,
    queue_length=3,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 56.3 s, sys: 408 ms, total: 56.7 s
# Wall time: 57 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 5 - Score: 0.695

# %%
container = ALL_TESTS[1]['container']
shapes = ALL_TESTS[1]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=12,
    step_portion=8,
    n_rotations=16,
    queue_length=3,
    n_search=10
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 47.9 s, sys: 302 ms, total: 48.2 s
# Wall time: 48.6 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 104 - Score: 0.558

# %%
container = ALL_TESTS[2]['container']
shapes = ALL_TESTS[2]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=12,
    step_portion=2,
    n_rotations=32,
    queue_length=3,
    n_search=100
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 18.6 s, sys: 171 ms, total: 18.8 s
# Wall time: 19 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 4 - Score: 0.692

# %%
container = ALL_TESTS[3]['container']
shapes = ALL_TESTS[3]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=10
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 47.4 s, sys: 331 ms, total: 47.8 s
# Wall time: 48.2 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 80 - Score: 0.598

# %%
container = ALL_TESTS[4]['container']
shapes = ALL_TESTS[4]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=3,
    n_neighbors=5,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 12.5 s, sys: 131 ms, total: 12.6 s
# Wall time: 12.7 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 2 - Score: 0.691

# %%
container = ALL_TESTS[5]['container']
shapes = ALL_TESTS[5]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=10
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 32.5 s, sys: 209 ms, total: 32.7 s
# Wall time: 32.8 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 53 - Score: 0.567

# %%
container = ALL_TESTS[6]['container']
shapes = ALL_TESTS[6]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=8,
    step_portion=2,
    queue_length=10,
    n_rotations=32,
    n_search=100
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPU times: user 28.8 s, sys: 240 ms, total: 29 s
# Wall time: 29.1 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 2 - Score: 0.628

# %%
container = ALL_TESTS[7]['container']
shapes = ALL_TESTS[7]['shapes']

# %%
# %%time
packer = IrregularPackerIntensification(
    container,
    shapes,
    intersection_threshold=40,
    max_iter=1000,
    shots=1,
    n_neighbors=16,
    step_portion=8,
    queue_length=3,
    n_rotations=32,
    n_search=10
)
df_sol = packer.pack()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 59 s, sys: 402 ms, total: 59.4 s
# Wall time: 59.7 s

# %%
print('Number of items:', len(df_sol), '- Score:', round(packer.score(), 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of items: 50 - Score: 0.491
