# %%
# %env DISABLE_PROGRESS_BAR=True

# %%
from shapely.geometry import GeometryCollection

from packer import CirclePackerPSO
from tests import ALL_TESTS

# %%
container = ALL_TESTS[0]['container']
radius = ALL_TESTS[0]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# CPU times: user 15min 50s, sys: 32.7 s, total: 16min 22s
# Wall time: 46min 31s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
# Out:
# Number of circles: 23 - Score: 0.368

# %%
container = ALL_TESTS[1]['container']
radius = ALL_TESTS[1]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()
# Out:
# CPU times: user 1min 15s, sys: 2.38 s, total: 1min 17s
# Wall time: 1min 17s

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[2]['container']
radius = ALL_TESTS[2]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[3]['container']
radius = ALL_TESTS[3]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[4]['container']
radius = ALL_TESTS[4]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[5]['container']
radius = ALL_TESTS[5]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[6]['container']
radius = ALL_TESTS[6]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])

# %%
container = ALL_TESTS[7]['container']
radius = ALL_TESTS[7]['radius']

# %%
# %%time
packer = CirclePackerPSO(
    container,
    radius,
    phi_p=1,
    phi_g=1,
    w=0.1,
    n_particles=100,
    n_iterations=20,
    n_circle_iter=8,
)
packer.pack()

# %%
_packer = packer.get_packer()
df_sol = _packer.drop_external(packer.global_optimum_position.copy())
_packer.drop_intersected(df_sol)
print('Number of circles:', len(df_sol), '- Score:', round(packer.global_optimum, 3))
GeometryCollection([container, *df_sol['item']])
